# %% [markdown]
# # DETECÇÃO DE FACES COM OPEN CV
# #### df = detectar face

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
imagem = cv2.imread('imagens/pessoas.jpg')

imagem.shape
# Out:
# (799, 1200, 3)

# %%
imagem = cv2.resize(imagem,(800, 600))
imagem.shape
# Out:
# (600, 800, 3)

# %%
# total de pixels na imagem x 
600*800*3, 600*800
# Out:
# (1440000, 480000)

# %%
imagemGray = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)
imagemGray.shape
# Out:
# (600, 800)

# %%
detectar_face = cv2.CascadeClassifier('hc/haarcascade_frontalface_default.xml')
